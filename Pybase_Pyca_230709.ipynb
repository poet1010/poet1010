# %% [markdown]
# <a href="https://colab.research.google.com/github/poet1010/poet1010/blob/main/Pybase_Pyca_230709.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# init setup
from pycaret.regression import *
clf3 = setup(data = data_sel, target = 'WAR', feature_selection=True, n_features_to_select=4,
            feature_selection_method = 'sequential', session_id=123)
# Out:
# <style type="text/css">
# #T_76be9_row8_col1, #T_76be9_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_76be9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76be9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_76be9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76be9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76be9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_76be9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_76be9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76be9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_76be9_row1_col1" class="data row1 col1" >WAR</td>
#     </tr>
#     <tr>
# ...

# %%
# init setup
from pycaret.regression import *
clf3 = setup(data = data_sel, target = 'WAR', feature_selection=True, n_features_to_select=4,
            feature_selection_method = 'sequential', session_id=123)
# Out:
# <style type="text/css">
# #T_76be9_row8_col1, #T_76be9_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_76be9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76be9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_76be9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76be9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76be9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_76be9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_76be9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76be9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_76be9_row1_col1" class="data row1 col1" >WAR</td>
#     </tr>
#     <tr>
# ...

# %%
# init setup
from pycaret.regression import *
clf3 = setup(data = data_sel, target = 'WAR', feature_selection=True, n_features_to_select=4,
            feature_selection_method = 'sequential', session_id=123)
# Out:
# <style type="text/css">
# #T_76be9_row8_col1, #T_76be9_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_76be9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76be9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_76be9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76be9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76be9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_76be9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_76be9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76be9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_76be9_row1_col1" class="data row1 col1" >WAR</td>
#     </tr>
#     <tr>
# ...

# %%
# !pip install pybaseball

# %%
# !pip install pycaret

# %%
# !pip install shap

# %%
# !pip install pandas_profiling

# %%
import pandas as pd

# %%
from pybaseball import pitching_stats
data = pitching_stats(2016,2022)
data.columns[61:75]
# Out:
# Index(['Dollars', 'tERA', 'xFIP', 'WPA', '-WPA', '+WPA', 'RE24', 'REW', 'pLI',
#        'inLI', 'gmLI', 'exLI', 'Pulls', 'WPA/LI'],
#       dtype='object')

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#       IDfg  Season           Name   Team  Age   W   L  WAR   ERA   G  ...  \
# 1    10954    2018   Jacob deGrom    NYM   30  10   9  9.0  1.70  32  ...
# 64   10603    2017     Chris Sale    BOS   28  17   8  7.6  2.90  32  ...
# 27   13125    2019    Gerrit Cole    HOU   28  20   5  7.5  2.50  33  ...
# 31    3137    2018   Max Scherzer    WSN   33  18   7  7.5  2.53  33  ...
# 21   19361    2021  Corbin Burnes    MIL   26  11   5  7.5  2.43  28  ...
# ..     ...     ...            ...    ...  ...  ..  ..  ...   ...  ..  ...
# 356   7593    2021   Jordan Lyles    TEX   30  10  13  0.1  5.15  32  ...
# 373  15474    2018  Lucas Giolito    CHW   23  10  13  0.1  6.13  32  ...
# 304  13834    2020     Alec Mills    CHC   28   5   5  0.1  4.48  11  ...
# 374  15440    2020   Matthew Boyd    DET   29   3   7 -0.1  6.71  12  ...
# 372   7059    2016  James Shields  - - -   34   6  19 -1.0  5.85  33  ...
#
#        LA  Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  \
# ...

# %%
# import ydata_profiling

# %%
# import pandas_profiling

# %%
import pandas as pd; import numpy as np
# Step: Select columns
data_sel = data[['Age', 'W', 'L', 'WAR', 'ERA', 'IP', 'WHIP', 'BABIP', 'FIP', 'xFIP']]

# %%
data_sel
# Out:
#      Age   W   L  WAR   ERA     IP  WHIP  BABIP   FIP  xFIP
# 1     30  10   9  9.0  1.70  217.0  0.91  0.281  1.99  2.60
# 64    28  17   8  7.6  2.90  214.1  0.97  0.301  2.45  2.65
# 27    28  20   5  7.5  2.50  212.1  0.89  0.275  2.64  2.48
# 31    33  18   7  7.5  2.53  220.2  0.91  0.265  2.65  3.06
# 21    26  11   5  7.5  2.43  167.0  0.94  0.309  1.63  2.30
# ..   ...  ..  ..  ...   ...    ...   ...    ...   ...   ...
# 356   30  10  13  0.1  5.15  180.0  1.39  0.299  5.34  4.73
# 373   23  10  13  0.1  6.13  173.1  1.48  0.268  5.56  5.46
# 304   28   5   5  0.1  4.48   62.1  1.16  0.233  5.44  4.61
# 374   29   3   7 -0.1  6.71   60.1  1.48  0.308  5.78  4.97
# 372   34   6  19 -1.0  5.85  181.2  1.60  0.302  6.01  5.21
#
# [375 rows x 10 columns]

# %%
# init setup
from pycaret.regression import *
clf3 = setup(data = data_sel, target = 'WAR', feature_selection=True, n_features_to_select=4,
            feature_selection_method = 'sequential', session_id=123)
# Out:
# <style type="text/css">
# #T_76be9_row8_col1, #T_76be9_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_76be9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76be9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_76be9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76be9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76be9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_76be9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_76be9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76be9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_76be9_row1_col1" class="data row1 col1" >WAR</td>
#     </tr>
#     <tr>
# ...

# %%
# !pip install pycaret[mlops]

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_b07fe th {
#   text-align: left;
# }
# ...

# %%
#plot_model
plot_model(best, plot='residuals')

# %%
#plot_model
plot_model(best, plot='error')

# %%
#plot_model
plot_model(best, plot='cooks')

# %%
#plot_model
plot_model(best, plot='rfe')

# %%
#plot_model
plot_model(best, plot='feature')

# %%
#plot_model
plot_model(best, plot='parameter')
# Out:
#                              Parameters
# bootstrap                         False
# ccp_alpha                           0.0
# criterion                 squared_error
# max_depth                          None
# max_features                        1.0
# max_leaf_nodes                     None
# max_samples                        None
# min_impurity_decrease               0.0
# min_samples_leaf                      1
# min_samples_split                     2
# min_weight_fraction_leaf            0.0
# n_estimators                        100
# n_jobs                               -1
# oob_score                         False
# random_state                        123
# verbose                               0
# warm_start                        False

# %%
#plot_model
plot_model(best, plot='learning')

# %%
#plot_model
plot_model(best, plot='vc')

# %%
#plot_model
plot_model(best, plot='manifold')

# %%
et = create_model('et')
# Out:
# <style type="text/css">
# #T_a9d96_row10_col0, #T_a9d96_row10_col1, #T_a9d96_row10_col2, #T_a9d96_row10_col3, #T_a9d96_row10_col4, #T_a9d96_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a9d96" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9d96_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a9d96_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a9d96_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a9d96_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a9d96_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a9d96_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_dt = tune_model(et, optimize = 'R2')
# Out:
# <style type="text/css">
# #T_8b4e7_row10_col0, #T_8b4e7_row10_col1, #T_8b4e7_row10_col2, #T_8b4e7_row10_col3, #T_8b4e7_row10_col4, #T_8b4e7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8b4e7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b4e7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8b4e7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8b4e7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8b4e7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8b4e7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8b4e7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
esm = ensemble_model(et)
# Out:
# <style type="text/css">
# #T_0557c_row10_col0, #T_0557c_row10_col1, #T_0557c_row10_col2, #T_0557c_row10_col3, #T_0557c_row10_col4, #T_0557c_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0557c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0557c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0557c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0557c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0557c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0557c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0557c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
type(esm)
# Out:
# sklearn.ensemble._bagging.BaggingRegressor

# %%
print(esm)
# Out:
# BaggingRegressor(estimator=ExtraTreesRegressor(n_jobs=-1, random_state=123),
#                  random_state=123)

# %%
import shap

# %%
# interpret model
interpret_model(et)

# %%
# interpret model
interpret_model(et)

# %%
interpret_model(et, plot = 'correlation')

# %%
# Partial Dependence Plot
interpret_model(et, plot = 'reason')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
# interpret model
interpret_model(et, plot = 'reason', observation = 1)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
# !pip install interpret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 44.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.0/758.0 kB 34.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 55.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 41.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 18.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 13.0 MB/s eta 0:00:00
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283839 sha256=9db12e25f871604b78de9f0dd1df33e5be0c51ef08273fd9079ad43392a20bc6
#   Stored in directory: /root/.cache/pip/wheels/fd/a2/af/9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# ...

# %%
# !pip install explainerdashboard

# %%
# !pip install pycaret[analysis]

# %%
# init setup
from pycaret.regression import *
clf3 = setup(data = data_sel, target = 'WAR', feature_selection=True, n_features_to_select=6,
            feature_selection_method = 'sequential', session_id=123)
# Out:
# <style type="text/css">
# #T_015e8_row8_col1, #T_015e8_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_015e8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_015e8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_015e8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_015e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_015e8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_015e8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_015e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_015e8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_015e8_row1_col1" class="data row1 col1" >WAR</td>
#     </tr>
#     <tr>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_e6b71 th {
#   text-align: left;
# }
# ...

# %%
data.head()
# Out:
#     IDfg  Season            Name Team  Age   W   L  WAR   ERA   G  ...  LA  \
# 2     60    2000   Randy Johnson  ARI   36  19   7  9.6  2.64  35  ... NaN
# 0    200    2000  Pedro Martinez  BOS   28  18   6  9.4  1.74  29  ... NaN
# 3    104    2000     Greg Maddux  ATL   34  19   9  7.2  3.00  35  ... NaN
# 1    642    2000     Kevin Brown  LAD   35  13   6  6.8  2.58  33  ... NaN
# 14   837    2000    Mike Mussina  BAL   31  11  15  6.4  3.79  34  ... NaN
#
#     Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%  CSW%  xERA
# 2       NaN      NaN    NaN      NaN       NaN       0    NaN   NaN   NaN
# 0       NaN      NaN    NaN      NaN       NaN       0    NaN   NaN   NaN
# 3       NaN      NaN    NaN      NaN       NaN       0    NaN   NaN   NaN
# 1       NaN      NaN    NaN      NaN       NaN       0    NaN   NaN   NaN
# 14      NaN      NaN    NaN      NaN       NaN       0    NaN   NaN   NaN
#
# [5 rows x 334 columns]

# %%
from pybaseball import batting_stats

# get all of this season's batting data so far
data = batting_stats(2020,2022)
data.head()
# Out:
#      IDfg  Season                Name Team  Age    G   AB   PA    H   1B  ...  \
# 1   15640    2022         Aaron Judge  NYY   30  157  570  696  177   87  ...
# 43  11493    2022       Manny Machado  SDP   29  150  578  644  172  102  ...
# 44   9777    2022       Nolan Arenado  STL   31  148  557  620  163   90  ...
# 18  19709    2021  Fernando Tatis Jr.  SDP   22  130  478  546  135   62  ...
# 8    9218    2022    Paul Goldschmidt  STL   34  151  561  651  178  102  ...
#
#     maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xBA  xSLG  xwOBA  L-WAR
# 1   118.4      246     0.609     404  0.169  0.287  NaN   NaN    NaN   11.2
# 43  112.4      219     0.490     447  0.126  0.243  NaN   NaN    NaN    6.6
# 44  111.4      190     0.389     489  0.155  0.241  NaN   NaN    NaN    7.2
# 18  116.6      183     0.556     329  0.102  0.270  NaN   NaN    NaN    6.2
# 8   112.3      200     0.469     426  0.196  0.295  NaN   NaN    NaN    8.0
#
# [5 rows x 320 columns]

# %%
data.shape
# Out:
# (404, 320)

# %%
import pandas as pd; import numpy as np
# Step: Select columns
data_bat = data[['H', 'RBI', 'AVG', 'BABIP', 'OPS', 'OBP', 'wRC+', 'wOBA','WAR']]

# %%
data_bat.describe()
# Out:
#                IDfg           H         RBI         AVG       BABIP  \
# count    404.000000  404.000000  404.000000  404.000000  404.000000
# mean   13717.433168  108.618812   58.423267    0.261356    0.299995
# std     4980.330047   45.822706   27.553270    0.031112    0.037747
# min     1744.000000   32.000000   10.000000    0.176000    0.203000
# 25%    10815.000000   57.000000   33.000000    0.241000    0.276000
# 50%    14128.000000  122.000000   58.500000    0.262000    0.300000
# 75%    17919.000000  144.250000   78.000000    0.280250    0.325000
# max    27506.000000  199.000000  131.000000    0.364000    0.412000
#
#               OPS         OBP        wRC+        wOBA         WAR
# count  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     0.784611    0.336312  114.517327    0.337691    2.360891
# std      0.094845    0.034431   24.429210    0.035810    1.880791
# min      0.552000    0.238000   53.000000    0.245000   -1.100000
# ...

# %%
data.columns[:20]
# Out:
# Index(['IDfg', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B',
#        '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SF'],
#       dtype='object')

# %%
from pycaret.regression import *

reg = setup(data=data_bat, target='WAR', feature_selection=True, n_features_to_select=4, feature_selection_method = 'sequential')

# clf3 = setup(data = data_sel, target = 'WAR', feature_selection=True, n_features_to_select=6,
#             feature_selection_method = 'sequential', session_id=123)
# Out:
# <style type="text/css">
# #T_adb34_row8_col1, #T_adb34_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_adb34" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adb34_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_adb34_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adb34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_adb34_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_adb34_row0_col1" class="data row0 col1" >7107</td>
#     </tr>
#     <tr>
#       <th id="T_adb34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_adb34_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_adb34_row1_col1" class="data row1 col1" >WAR</td>
#     </tr>
#     <tr>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_aa507 th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predictions = predict_model(best, data=data_bat)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_dbebf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbebf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dbebf_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_dbebf_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_dbebf_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_dbebf_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_dbebf_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_dbebf_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbebf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbebf_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_dbebf_row0_col1" class="data row0 col1" >0.5821</td>
# ...

# %%
#plot_model
plot_model(best, plot='feature')

# %%
#plot_model
plot_model(best, plot='rfe')

# %%
#plot_model
plot_model(best, plot='parameter')
# Out:
#                   Parameters
# boosting_type           gbdt
# class_weight            None
# colsample_bytree         1.0
# importance_type        split
# learning_rate            0.1
# max_depth                 -1
# min_child_samples         20
# min_child_weight       0.001
# min_split_gain           0.0
# n_estimators             100
# n_jobs                    -1
# num_leaves                31
# objective               None
# random_state            7107
# reg_alpha                0.0
# reg_lambda               0.0
# silent                  warn
# subsample                1.0
# subsample_for_bin     200000
# subsample_freq             0

# %%
#plot_model
plot_model(best, plot='learning')

# %%
#plot_model
plot_model(best, plot='vc')

# %%
#plot_model
plot_model(best, plot='manifold')

# %%
lgb = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_22b79_row10_col0, #T_22b79_row10_col1, #T_22b79_row10_col2, #T_22b79_row10_col3, #T_22b79_row10_col4, #T_22b79_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_22b79" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22b79_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_22b79_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_22b79_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_22b79_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_22b79_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_22b79_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_dt = tune_model(lgb, optimize = 'R2')
# Out:
# <style type="text/css">
# #T_7379a_row10_col0, #T_7379a_row10_col1, #T_7379a_row10_col2, #T_7379a_row10_col3, #T_7379a_row10_col4, #T_7379a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7379a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7379a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7379a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7379a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7379a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7379a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7379a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
interpret_model(lgb)

# %%
interpret_model(lgb, plot = 'correlation')

# %%
# Partial Dependence Plot
interpret_model(lgb, plot = 'reason')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
lasso = create_model('lasso')

# %%
tuned_dt = tune_model(lasso, optimize = 'R2')

# %%
esm = ensemble_model(lasso)

# %%
type(lasso)
# Out:
# sklearn.linear_model._coordinate_descent.Lasso

# %%
print(lasso)
# Out:
# Lasso(random_state=5523)

# %%
import shap

# %%
interpret_model(lasso)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-767bb2655b2e> in <cell line: 1>()
# ----> 1 interpret_model(lasso)
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/pycaret/regression/functional.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1830     """
#    1831
# -> 1832     return _CURRENT_EXPERIMENT.interpret_model(
#    1833         estimator=estimator,
#    1834         plot=plot,
#
# ...

# %%
from pybaseball import fielding_stats
data2 = fielding_stats(2020,2022)
data2.columns
# Out:
# Index(['IDfg', 'Season', 'Name', 'Team', 'Pos', 'G', 'GS', 'Inn', 'PO', 'A',
#        'E', 'FE', 'TE', 'DP', 'DPS', 'DPT', 'DPF', 'Scp', 'SB', 'CS', 'PB',
#        'WP', 'FP', 'TZ', 'rSB', 'rGDP', 'rARM', 'rGFP', 'rPM', 'DRS', 'BIZ',
#        'Plays', 'RZR', 'OOZ', 'TZL', 'FSR', 'ARM', 'DPR', 'RngR', 'ErrR',
#        'UZR', 'UZR/150', 'CPP', 'RPP', 'Def', '0%', '# 0%', '1-10%', '# 1-10%',
#        '10-40%', '# 10-40%', '40-60%', '# 40-60%', '60-90%', '# 60-90%',
#        '90-100%', '# 90-100%', 'rSZ', 'rCERA', 'rTS', 'FRM', 'OAA', 'RAA'],
#       dtype='object')

# %%
data2.shape
# Out:
# (148, 63)

# %%
data2_fie = data2[['IDfg', 'DPR', 'RngR', 'ErrR','UZR']]

# %%
import pandas as pd; import numpy as np
# Step: Select columns
data_sel = data[['IDfg','Age', 'W', 'L', 'WAR', 'ERA', 'IP', 'WHIP', 'BABIP', 'FIP', 'xFIP']]

# %%
from pycaret.regression import *
s = setup(data_sel, target = 'WAR', session_id = 123)
# Out:
# <style type="text/css">
# #T_af91b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_af91b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af91b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_af91b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af91b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af91b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_af91b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_af91b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_af91b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_af91b_row1_col1" class="data row1 col1" >WAR</td>
#     </tr>
#     <tr>
#       <th id="T_af91b_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# functional API
best = compare_models()
# Out:
# <style type="text/css">
# #T_ec714 th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# GradientBoostingRegressor(random_state=123)

# %%
# functional API
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
gbr = create_model('gbr')
# Out:
# <style type="text/css">
# #T_35a4e_row10_col0, #T_35a4e_row10_col1, #T_35a4e_row10_col2, #T_35a4e_row10_col3, #T_35a4e_row10_col4, #T_35a4e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_35a4e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35a4e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_35a4e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_35a4e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_35a4e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_35a4e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_35a4e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
interpret_model(gbr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-2054fcc8410e> in <cell line: 1>()
# ----> 1 interpret_model(gbr)
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/pycaret/regression/functional.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1830     """
#    1831
# -> 1832     return _CURRENT_EXPERIMENT.interpret_model(
#    1833         estimator=estimator,
#    1834         plot=plot,
#
# ...

# %%
from pybaseball import batting_stats

# get all of this season's batting data so far
data = batting_stats(2020)

# %%
data.columns

# %%
data.head()

# %%
data.shape
# Out:
# (1110, 320)

# %%
import pandas as pd; import numpy as np
# Step: Select columns
data_sel = data[['IDfg','H', 'RBI', 'AVG', 'BABIP', 'OPS', 'OBP', 'wRC+', 'wOBA','WAR']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61ba9fcb71e0> in <cell line: 3>()
#       1 import pandas as pd; import numpy as np
#       2 # Step: Select columns
# ----> 3 data_sel = data[['IDfg','H', 'RBI', 'AVG', 'BABIP', 'OPS', 'OBP', 'wRC+', 'wOBA','WAR']]
#
# NameError: name 'data' is not defined

# %%
data2.columns
# Out:
# Index(['IDfg', 'Season', 'Name', 'Team', 'Pos', 'G', 'GS', 'Inn', 'PO', 'A',
#        'E', 'FE', 'TE', 'DP', 'DPS', 'DPT', 'DPF', 'Scp', 'SB', 'CS', 'PB',
#        'WP', 'FP', 'TZ', 'rSB', 'rGDP', 'rARM', 'rGFP', 'rPM', 'DRS', 'BIZ',
#        'Plays', 'RZR', 'OOZ', 'TZL', 'FSR', 'ARM', 'DPR', 'RngR', 'ErrR',
#        'UZR', 'UZR/150', 'CPP', 'RPP', 'Def', '0%', '# 0%', '1-10%', '# 1-10%',
#        '10-40%', '# 10-40%', '40-60%', '# 40-60%', '60-90%', '# 60-90%',
#        '90-100%', '# 90-100%', 'rSZ', 'rCERA', 'rTS', 'FRM', 'OAA', 'RAA'],
#       dtype='object')

# %%
from pybaseball import fielding_stats
data2 = fielding_stats(2020)
data2.head()
# Out:
#     IDfg  Season               Name Team Pos   G  GS    Inn   PO    A  ...  \
# 0  11038    2020    Kevin Kiermaier  TBR  CF  46  41  350.2   86    6  ...
# 1  12916    2020   Francisco Lindor  CLE  SS  58  58  508.0   79  128  ...
# 2   9774    2020  Christian Vazquez  BOS   C  42  41  356.0  370   19  ...
# 3  12979    2020        Javier Baez  CHC  SS  56  56  469.1   86  159  ...
# 4  12147    2020         Nick Ahmed  ARI  SS  57  56  484.1   61  121  ...
#
#    60-90%  # 60-90%  90-100%  # 90-100%  rSZ  rCERA  rTS  FRM  OAA  RAA
# 0     NaN       NaN      NaN        NaN  NaN    NaN  NaN  NaN  4.0  3.0
# 1     NaN       NaN      NaN        NaN  NaN    NaN  NaN  NaN  8.0  6.0
# 2     NaN       NaN      NaN        NaN  2.0    1.0  NaN  4.7  NaN  NaN
# 3     NaN       NaN      NaN        NaN  NaN    NaN  NaN  NaN  9.0  7.0
# 4     NaN       NaN      NaN        NaN  NaN    NaN  NaN  NaN  8.0  6.0
#
# [5 rows x 63 columns]

# %%
data2_fie = data2[['IDfg','DRS', 'UZR']]

# %%
data2_sel
# Out:
#       IDfg  DRS   UZR
# 0    19339    3   5.2
# 1    11265    8   2.8
# 2    18314    9   0.9
# 3    12916    4  -0.1
# 4    11739   11   NaN
# ..     ...  ...   ...
# 305  19198   -2  -0.3
# 306  16478  -14 -10.0
# 307  11737   -8  -6.9
# 308  20123   -2  -2.0
# 309  19566   -9   0.0
#
# [310 rows x 3 columns]

# %%
# Step: Left Join with data_sel where WAR=WAR
data_join = pd.merge(data_bat, data2_sel, how='left', on=['IDfg'])

# %%
data_join.head()
# Out:
#     IDfg    H  RBI    AVG  BABIP    OPS    OBP  wRC+   wOBA   WAR   DRS   UZR
# 0  15640  177  131  0.311  0.340  1.111  0.425   207  0.458  11.5  11.0   3.4
# 1  11493  172  102  0.298  0.337  0.898  0.366   152  0.382   7.4  -3.0  -0.9
# 2  11493  172  102  0.298  0.337  0.898  0.366   152  0.382   7.4   6.0   5.1
# 3  11493  172  102  0.298  0.337  0.898  0.366   152  0.382   7.4   7.0   2.8
# 4   9777  163  103  0.293  0.290  0.891  0.358   151  0.381   7.3  19.0  13.0

# %%
# Step: Drop columns
data_drop = data_join.drop(columns=['IDfg'])

# %%
from pycaret.regression import *
s = setup(data_drop, target = 'WAR', session_id = 123)
# Out:
# <style type="text/css">
# #T_5af0a_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5af0a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5af0a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5af0a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5af0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5af0a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5af0a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5af0a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5af0a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5af0a_row1_col1" class="data row1 col1" >WAR</td>
#     </tr>
#     <tr>
#       <th id="T_5af0a_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# functional API
best = compare_models()
# Out:
# <style type="text/css">
# #T_a22df th {
#   text-align: left;
# }
# ...

# %%
# functional API
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# functional API
predictions = predict_model(best, data=data_drop)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_41fce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41fce_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_41fce_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_41fce_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_41fce_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_41fce_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_41fce_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_41fce_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41fce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41fce_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_41fce_row0_col1" class="data row0 col1" >0.1419</td>
# ...

# %%
et = create_model('et')

# %%
import shap

# %%
# interpret model
interpret_model(et, use_train_data=True)

# %%
from sklearn.linear_model import RANSACRegressor
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples=200, n_features=2, noise=4.0, random_state=0)

# %%
reg = RANSACRegressor(random_state=0).fit(X, y)

# %%
reg.score(X, y)
# Out:
# 0.9885538665570653

# %%
reg.predict(X[:1,])
# Out:
# array([-31.94170869])
